# %%
import pandas as pd
import numpy as np

from bokeh.plotting import figure, output_file, show
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.neighbors import kde

import pandas_profiling

plt.style.use('ggplot')
sns.set(style="whitegrid")

# %matplotlib inline
# Out:
# /Users/Andrew/anaconda3/lib/python3.6/site-packages/pandas_profiling/plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/Andrew/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/Andrew/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f3f60c593bdd>", line 5, in <module>
#     import seaborn as sns
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/seaborn/__init__.py", line 6, in <module>
#     from .rcmod import *
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/seaborn/rcmod.py", line 8, in <module>
#     from . import palettes, _orig_rc_params
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/seaborn/palettes.py", line 12, in <module>
#     from .utils import desaturate, set_hls_values, get_color_cycle
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/seaborn/utils.py", line 12, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 69, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/Users/Andrew/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)

# %% [markdown]
# # Import, explore and edit data.
# - Changed column titles to make them easier to work with.
# - Number of uses was considered and object and needed to be changed to an integer in order to work with.

# %%
df = pd.read_csv('./account_usage_data.csv')

# %%
df.head()
# Out:
#   Usage Date Account Creation Date  Days Since Account Started Number of Uses
# 0    7/29/18               7/29/18                           0            514
# 1    7/30/18               7/30/18                           0            429
# 2    7/30/18               7/29/18                           1             29
# 3    7/31/18               7/30/18                           1             58
# 4    7/31/18               7/31/18                           0            497

# %%
df.tail()
# Out:
#     Usage Date Account Creation Date  Days Since Account Started  \
# 495    8/29/18               8/14/18                          15
# 496    8/29/18               8/17/18                          12
# 497    8/29/18               8/22/18                           7
# 498    8/29/18                8/4/18                          25
# 499    8/29/18                8/1/18                          28
#
#     Number of Uses
# 495             26
# 496             91
# 497             39
# 498            210
# 499             48

# %%
# Change column names to make them easier to work with.

df.rename(columns = {'Usage Date':'usage_date', 'Account Creation Date':'creation_date', 
                     'Days Since Account Started':'days_since_account_started', 'Number of Uses':'number_of_uses'},
                      inplace=True)

# %%
df.dtypes
# Out:
# usage_date                    object
# creation_date                 object
# days_since_account_started     int64
# number_of_uses                object
# dtype: object

# %%
# Remove commas from number of uses column and change from object into an integer.

df['number_of_uses'] = df['number_of_uses'].str.replace(',','').astype('int64')

# %%
df.dtypes
# Out:
# usage_date                    object
# creation_date                 object
# days_since_account_started     int64
# number_of_uses                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# usage_date                    500 non-null object
# creation_date                 500 non-null object
# days_since_account_started    500 non-null int64
# number_of_uses                500 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 15.7+ KB

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>500 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>15.7 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>32.2 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_days_since_account_started"><code>days_since_account_started</code></a> has 31 / 6.2% zeros <span class="label label-info">Zeros</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_creation_date">creation_date<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>31</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>6.2%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (n)</th>
#             <td>0</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-6 collapse in" id="minifreqtable6253174191966117132">
#     <table class="mini freq">
#         <tr class="">
#     <th>7/29/18</th>
#     <td>
#         <div class="bar" style="width:8%" data-toggle="tooltip" data-placement="right" data-html="true"
#              data-delay=500 title="Percentage: 6.2%"

# %% [markdown]
# ## Maximum, Minimum, and Median

# %%
# Max and Min of number of uses.
df.number_of_uses.max(), df.number_of_uses.min()
# Out:
# (5157, 0)

# %%
# Max and Min of days since the accounts started.
df.days_since_account_started.max(), df.days_since_account_started.min()
# Out:
# (30, 0)

# %%
# Mean of number of uses.
df.number_of_uses.mean()
# Out:
# 512.82

# %%
# Mean of days since account started. 
df.days_since_account_started.mean()
# Out:
# 10.098

# %%
# Median of number of uses.
df.number_of_uses.median()
# Out:
# 78.0

# %%
# Median days since account started. 
df.days_since_account_started.median()
# Out:
# 9.0

# %% [markdown]
# ## Plot out the Data

# %%
sns.set(color_codes=True)
for column in ['number_of_uses']:
    plt.figure(figsize=(20,14))
    plt.rcParams['axes.labelsize'] = 30
    plt.rcParams['axes.titlesize'] = 30
    sns.set(font_scale = 2)
    ax = sns.regplot(x=column, y='days_since_account_started', data=df, robust=True, ci=None)
    ax.set(ylabel='Days Since Account Started', 
       xlabel='Number of Uses', 
       title='Number of Uses Compared to Days Since Account Started')

# %%
# Switch the axes. 

sns.set(color_codes=True)
for column in ['days_since_account_started']:
    plt.figure(figsize=(20,14))
    plt.rcParams['axes.labelsize'] = 30
    plt.rcParams['axes.titlesize'] = 30
    sns.set(font_scale = 2)
    ax = sns.regplot(x=column, y='number_of_uses', data=df)
    ax.set(ylabel='Number of Uses', 
       xlabel='Days Since Account Started', 
       title='Number of Uses Compared to Days Since Account Started')

# %%
df_uses = df.groupby(df.days_since_account_started, as_index=False).agg({
        'number_of_uses': np.sum,
#         'days_since_account_started': lambda x: x.iloc[0]
                }).sort_values(by='number_of_uses', ascending=False)

# %%
sns.set(color_codes=True)
for column in ['days_since_account_started']:
    plt.figure(figsize=(20,14))
    plt.rcParams['axes.labelsize'] = 30
    plt.rcParams['axes.titlesize'] = 30
    sns.set(font_scale = 2)
    ax = sns.regplot(x=column, y='number_of_uses', data=df_uses)
    ax.set(ylabel='Sum of Number of Uses', 
       xlabel='Days Since Account Statrted', 
       title='Total Sum Number of Uses Compared to Days of Account')

# %%
sns.set(style="ticks")
plt.figure(figsize=(20,14))
sns.pairplot(df)

# %%
sns.set(style="ticks")
plt.figure(figsize=(20,14))
sns.jointplot(x='days_since_account_started', y='number_of_uses', data=df, kind='hex', color="#4CB391")

# %% [markdown]
# # Kernel Density Estimations and Histograms

# %%
x = df['number_of_uses']

plt.figure(figsize=(20,14))
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['axes.titlesize'] = 30
sns.set(font_scale = 2)
ax = sns.kdeplot(x, shade=True, color='green')
ax.set(ylabel='Frequency', 
       xlabel='Number of Uses', 
       title='Kernel Density Estimation of Uses')
# Out:
# [Text(0,0.5,'Frequency'),
#  Text(0.5,0,'Number of Uses'),
#  Text(0.5,1,'Kernel Density Estimation of Uses')]

# %%
x = df['number_of_uses']

plt.figure(figsize=(20,14))
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['axes.titlesize'] = 30
sns.set(font_scale = 2)
ax = sns.distplot(x, color='green')
ax.set(ylabel='Frequency', 
       xlabel='Number of Uses', 
       title='Histogram of Uses')
# Out:
# [Text(0,0.5,'Frequency'),
#  Text(0.5,0,'Number of Uses'),
#  Text(0.5,1,'Histogram of Uses')]

# %%
y = df['days_since_account_started']

plt.figure(figsize=(20,14))
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['axes.titlesize'] = 30
ax = sns.kdeplot(y, shade=True, color='purple')
ax.set(ylabel='Frequency', 
       xlabel='Days Since Account Started', 
       title='Kernel Density Estimation of Days Since Account Started')
# Out:
# [Text(0,0.5,'Frequency'),
#  Text(0.5,0,'Days Since Account Started'),
#  Text(0.5,1,'Kernel Density Estimation of Days Since Account Started')]

# %%
plt.figure(figsize=(20,14))
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['axes.titlesize'] = 30
ax = sns.distplot(y, color='purple')
ax.set(ylabel='Frequency', 
       xlabel='Days Since Account Started', 
       title='Kernel Density Estimation of Days Since Account Started')
# Out:
# [Text(0,0.5,'Frequency'),
#  Text(0.5,0,'Days Since Account Started'),
#  Text(0.5,1,'Kernel Density Estimation of Days Since Account Started')]

# %% [markdown]
# # Linear Regression

# %%
x = df['days_since_account_started']
y = df['number_of_uses']


### Plot the data
# create a figure
fig = plt.figure(figsize=(15,7))
# get the axis of that figure
ax = plt.gca()

# plot a scatter plot on it with our data
ax.scatter(x, y, c='k')
ax.plot((df['days_since_account_started'].min(), df['days_since_account_started'].max()),
        (np.mean(df['number_of_uses']), np.mean(df['number_of_uses'])), 
         color='r');

# %%
df['Mean_Yhat'] = y.mean()

# %%
df.head()
# Out:
#   usage_date creation_date  days_since_account_started  number_of_uses  \
# 0    7/29/18       7/29/18                           0             514
# 1    7/30/18       7/30/18                           0             429
# 2    7/30/18       7/29/18                           1              29
# 3    7/31/18       7/30/18                           1              58
# 4    7/31/18       7/31/18                           0             497
#
#    Mean_Yhat
# 0     512.82
# 1     512.82
# 2     512.82
# 3     512.82
# 4     512.82

# %%
df.drop(['usage_date', 'creation_date'], axis=1)
# Out:
#    days_since_account_started  number_of_uses  Mean_Yhat
# 0                           0             514     512.82
# 1                           0             429     512.82
# 2                           1              29     512.82
# 3                           1              58     512.82
# 4                           0             497     512.82

# %%
# calculate MSE

df['Mean_Yhat_SE'] = np.square(df['number_of_uses'] - df['Mean_Yhat'])
df['Mean_Yhat_SE'].mean()
# Out:
# 852657.7555999995

# %%
# Calculate beta coefficients

y_bar = df['number_of_uses'].mean()
x_bar = df['days_since_account_started'].mean()
std_y = df['number_of_uses'].std()
std_x = df['days_since_account_started'].std()
r_xy = df.corr().loc['days_since_account_started','number_of_uses']
beta_1 = r_xy*(std_y/std_x)
beta_0 = y_bar - beta_1*x_bar

# %%
df['Linear_Yhat'] = beta_0 + beta_1*df['days_since_account_started']

# %%
np.square(df['number_of_uses'] - df['Linear_Yhat']).mean()
# Out:
# 800146.1350775203

# %%
x = df['days_since_account_started']
y = df['number_of_uses']

# create a figure
fig = plt.figure(figsize=(15,7))
# get the axis of that figure
ax = plt.gca()

# plot a scatter plot on it with our data
ax.scatter(x, y, c='k')
ax.plot(df['days_since_account_started'], df['Linear_Yhat'], color='r');

# %%
# Plot residuals.

# create a figure
fig = plt.figure(figsize=(15,7))
fig.set_figheight(8)
fig.set_figwidth(15)

# get the axis
ax = fig.gca()

# plot it
ax.scatter(x=df['days_since_account_started'], y=df['number_of_uses'], c='k')
ax.plot(df['days_since_account_started'], df['Linear_Yhat'], color='k');

# iterate over predictions
for _, row in df.iterrows():
    plt.plot((row['days_since_account_started'], row['days_since_account_started']), 
             (row['number_of_uses'], row['Linear_Yhat']), 'r-')

# %%
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
df2 = df.drop(['usage_date', 'creation_date'], axis=1)

# %%
y = df2['number_of_uses']
X = df2.drop(['number_of_uses'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
print(X.shape, y.shape)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (500, 4) (500,)
# (250, 4) (250,)
# (250, 4) (250,)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)

# %%
# MSE for train data.
np.mean((y_train - lm.predict(X_train)) ** 2)
# Out:
# 195037.59574513818

# %%
# MSE for test data.
np.mean((y_test - lm.predict(X_test)) ** 2)
# Out:
# 191438.0582485605

# %%
lm.score(X, y)
# Out:
# 0.773370000181525
